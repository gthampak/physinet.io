# %%
import os
import shutil
import random; random.seed(42)

import pandas as pd
import numpy as np
from tqdm import tqdm
from matplotlib import pyplot as plt
import torch
from torch import nn

from utils import *

# %%
Seq_train, seq_names = get_seq_list(train_dir)
# Out:
# 100%|██████████| 40/40 [00:27<00:00,  1.46it/s]

# %%
plt_x = [y[5] for y in Seq_train[20]]
plt_y = [y[4] for y in Seq_train[20]]
plot_pendulum(plt_x,plt_y)

# %%
seq_names[14]
# Out:
# '0.csv'
